# %%
from biomarker_rank import biomarker_rank
from DataLoader import Load_Labeling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 21.5 MB/s eta 0:00:0000:0100:01
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.2/31.2 MB 20.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.0/307.0 kB 84.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.4/43.4 MB 16.8 MB/s eta 0:00:0000:0100:01
# ...
#   WARNING: Building wheel for sklearn failed: [Errno 13] Permission denied: '/home/meji9086/.cache/pip/wheels/22'
# Failed to build sklearn
# ...
#   Running setup.py install for sklearn ... done
#   DEPRECATION: sklearn was installed using the legacy 'setup.py install' method, because a wheel could not be built for it. A possible replacement is to fix the wheel build issue reported above. Discussion can be found at https://github.com/pypa/pip/issues/8368
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 2.5 MB/s eta 0:00:00a 0:00:010m
# ...

# %%
file_name = 'data'
cancer_name = ['LUAD', 'LUSC']

data = Load_Labeling(file_name, cancer_name)
# Out:
# cancer : LUAD
# file : LUAD.txt
# cancer : LUSC
# file : LUSC.txt

# %%
rank, importance = biomarker_rank(data, models = [['RF', 'default'],['XGB' , {'colsample_bytree': 0.5, 'n_estimators': 200, 'subsample': 0.75}]])

# %%
rank
# Out:
#                   ranking_RF  ranking_XGB
# ?|100130426             2059          172
# ?|100133144             1620          172
# ?|100134869             2059           98
# ?|10357                  323           69
# ?|10431                 2059          172
# ...                      ...          ...
# ZYX|7791                2059          172
# ZZEF1|23140             2059          172
# ZZZ3|26009              2059          172
# psiTPTE22|387590        2059          172
# tAKR|389932             2059          172
#
# [20531 rows x 2 columns]

# %%
importance
# Out:
#                   importances_RF  importances_XGB
# ?|100130426             0.000000         0.000000
# ?|100133144             0.000048         0.000000
# ?|100134869             0.000000         0.000720
# ?|10357                 0.000355         0.001565
# ?|10431                 0.000000         0.000000
# ...                          ...              ...
# ZYX|7791                0.000000         0.000000
# ZZEF1|23140             0.000000         0.000000
# ZZZ3|26009              0.000000         0.000000
# psiTPTE22|387590        0.000000         0.000000
# tAKR|389932             0.000000         0.000000
#
# [20531 rows x 2 columns]
