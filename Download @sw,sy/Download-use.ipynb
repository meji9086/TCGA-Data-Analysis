# %%
from Download import Download_data

# %%
path = '/mnt/workspace/MyFiles/공모전' # 압축 해제 전 데이터 경로
genome_path = '/mnt/workspace/MyFiles/공모전/Data' # 압축 해제한 데이터 저장
genome_name = ['LUAD', 'LUSC'] #입력 받는 암 데이터 명

# %%
Download_data(genome_name)
