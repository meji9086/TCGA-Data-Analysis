# %%
from Modeling import model_rank
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv("/content/drive/MyDrive/암마커추출/data.csv", sep=',')
data
# Out:
#       ?|100130426  ?|100133144  ?|100134869   ?|10357    ?|10431  ?|136542  \
# 0             0.0      10.0113      11.2820   49.5994   848.9397       0.0
# 1             0.0       7.1957      12.4436   90.5117   924.0158       0.0
# 2             0.0       7.2453       6.0184   49.5366  1140.6781       0.0
# 3             0.0      11.3311       7.5740   82.8303   807.1729       0.0
# 4             0.0       3.2254       3.4942   72.5351   562.0037       0.0
# ...           ...          ...          ...       ...        ...       ...
# 1005          0.0      19.9503      47.1026  176.7177  1188.3278       0.0
# 1006          0.0      30.0872      15.2957  188.7215  1248.0303       0.0
# 1007          0.0      53.6593      33.3907  260.3332   789.3606       0.0
# 1008          0.0      72.5666      42.1832  160.1624   460.8626       0.0
# 1009          0.0      44.7501      23.6304   76.6488   805.9507       0.0
#
# ...

# %%
model_rank(data, ["RF", "XGB"], parameters={'RF':{'min_samples_leaf': 8}, 'XGB' : {'colsample_bytree': 0.5, 'n_estimators': 200, 'subsample': 0.75}})
# Out:
# (                  ranking_RF  ranking_XGB
#  ?|100130426             1176          379
#  ?|100133144             1176          379
#  ?|100134869             1176          379
#  ?|10357                  490          379
#  ?|10431                 1176          379
#  ...                      ...          ...
#  ZYX|7791                1176          379
#  ZZEF1|23140             1176          379
#  ZZZ3|26009              1176          379
#  psiTPTE22|387590        1176          379
#  tAKR|389932             1176          379
#
#  [20531 rows x 2 columns],
#  '----------------------------------------------------------------------------------------------------',
#                    importances_RF  importances_XGB
#  ?|100130426             0.000000              0.0
#  ?|100133144             0.000000              0.0
#  ?|100134869             0.000000              0.0
#  ?|10357                 0.000187              0.0
#  ?|10431                 0.000000              0.0
# ...
