# %%
from heatmap import heat_zscore
from heatmap import heat_minmax
from heatmap import heat_maxabs
from DataLoader import Load_Labeling

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
from DataLoader import Load_Labeling

# %%
filename = 'Data' # 다운로드한 데이터가 들어있는 파일 
cancer_list = ['LUAD', 'LUSC'] # 입력 받는 암 데이터 명
df = Load_Labeling(filename, cancer_list)
# Out:
# cancer : LUAD
# file : LUAD.rnaseqv2__illuminahiseq_rnaseqv2__unc_edu__Level_3__RSEM_genes_normalized__data.data.txt
# cancer : LUSC
# file : LUSC.rnaseqv2__illuminahiseq_rnaseqv2__unc_edu__Level_3__RSEM_genes_normalized__data.data.txt

# %%
genome_list=df.columns[:10]
genome_list
# Out:
# Index(['?|100130426', '?|100133144', '?|100134869', '?|10357', '?|10431',
#        '?|136542', '?|155060', '?|26823', '?|280660', '?|317712'],
#       dtype='object')

# %%
z_df = heat_zscore(df, cancer_list, genome_list)

# %%
mm_df = heat_minmax(df, cancer_list, genome_list)

# %%
ma_df = heat_maxabs(df, cancer_list, genome_list)
